# %%
import pandas as pd
import seaborn as sns
sns.set_theme(style='ticks')

faulty = pd.read_csv("./data/FaultyLost.txt")
# print(repair.info())
sns.relplot(
    data=faulty, x='%faulty', y='#lost', hue='protocol',
    kind='line',
)
